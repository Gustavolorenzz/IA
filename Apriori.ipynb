# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavolorenzz/IA/blob/main/Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Regras de associação**
#
# **Algoritmo Apriori**
#
# **Veja: https://www.youtube.com/watch?v=0v6PiOpsJi8**

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
from apyori import apriori
import pandas as pd

# %%
base = pd.read_csv('https://raw.githubusercontent.com/Gustavolorenzz/IA/main/Bases/Mercado.txt', header = None)
base
# Out:
#        0     1        2    3         4      5       6
# 0         Café           Pão  Manteiga
# 1  Leite        Cerveja  Pão  Manteiga
# 2         Café           Pão  Manteiga
# 3  Leite  Café           Pão  Manteiga
# 4               Cerveja
# 5                             Manteiga
# 6                        Pão
# 7                                              Feijão
# 8                                       Arroz  Feijão
# 9                                       Arroz

# %%
base.shape
# Out:
# (10, 7)

# %% [markdown]
# **O código a seguir altera a base de dados para colocar as ausências dos produtos**

# %%
#for column in base:
#     base[column]=base[column].fillna('~' + column)

# %%
#base

# %%
#base.shape

# %% [markdown]
# **Como estaremos treinando um modelo a priori, que recebe entradas em formato de lista, precisamos transformar o dataframe em uma lista de transações.**

# %%
transacoes = []
for i in range(len(base)):
  #print(i)
  #print(base_mercado1.values[i, 0])
  transacoes.append([str(base.values[i, j]) for j in range(base.shape[1])])

# %%
transacoes
# Out:
# [[' ', 'Café', ' ', 'Pão', 'Manteiga', ' ', ' '],
#  ['Leite', ' ', 'Cerveja', 'Pão', 'Manteiga', ' ', ' '],
#  [' ', 'Café', ' ', 'Pão', 'Manteiga', ' ', ' '],
#  ['Leite', 'Café', ' ', 'Pão', 'Manteiga', ' ', ' '],
#  [' ', ' ', 'Cerveja', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', 'Manteiga', ' ', ' '],
#  [' ', ' ', ' ', 'Pão', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', 'Feijão'],
#  [' ', ' ', ' ', ' ', ' ', 'Arroz', 'Feijão'],
#  [' ', ' ', ' ', ' ', ' ', 'Arroz', ' ']]

# %%
type(transacoes)
# Out:
# list

# %%
regras = apriori(transacoes, min_support = 0.3, min_confidence = 0.8)
saida = list(regras)
print(len(saida))
print(saida)
# Out:
# 12
# [RelationRecord(items=frozenset({' '}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({' ', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', ' '}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({' ', 'Pão'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pão'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Pão', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Pão'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Manteiga', 'Pão'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Pão'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Pão'}), items_add=frozenset({'Manteiga'}), confidence=0.8, lift=1.6)]), RelationRecord(items=frozenset({'Manteiga', ' ', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga', ' '}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({' ', 'Café'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Manteiga', 'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({' ', 'Café', 'Pão'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({' ', 'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({' ', 'Café'}), items_add=frozenset({'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Pão', 'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', ' ', 'Pão'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({' ', 'Pão'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Pão'}), items_add=frozenset({'Manteiga', ' '}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Manteiga', ' '}), items_add=frozenset({'Pão'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({' ', 'Pão'}), items_add=frozenset({'Manteiga'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Manteiga', 'Pão'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Pão', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga', 'Pão'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'Manteiga', 'Café'}), items_add=frozenset({'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Pão', 'Café'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Manteiga', ' ', 'Café', 'Pão'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga', ' ', 'Pão'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({' ', 'Café'}), items_add=frozenset({'Manteiga', 'Pão'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'Manteiga', 'Café'}), items_add=frozenset({' ', 'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Pão', 'Café'}), items_add=frozenset({'Manteiga', ' '}), confidence=1.0, lift= ...

# %% [markdown]
# **Vamos chamar executar o algoritmo apriori e armazenar as regras obtidas**

# %%
regras = apriori(transacoes, min_support = 0.3, min_confidence = 0.8)
saida = list(regras)
print(len(saida))
print(saida)
# Out:
# 12
# [RelationRecord(items=frozenset({' '}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({' ', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', ' '}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({' ', 'Pão'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pão'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Pão', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Pão'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Manteiga', 'Pão'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Pão'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Pão'}), items_add=frozenset({'Manteiga'}), confidence=0.8, lift=1.6)]), RelationRecord(items=frozenset({'Manteiga', ' ', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga', ' '}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({' ', 'Café'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Manteiga', 'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({' ', 'Café', 'Pão'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({' ', 'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({' ', 'Café'}), items_add=frozenset({'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Pão', 'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', ' ', 'Pão'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({' ', 'Pão'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Pão'}), items_add=frozenset({'Manteiga', ' '}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Manteiga', ' '}), items_add=frozenset({'Pão'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({' ', 'Pão'}), items_add=frozenset({'Manteiga'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Manteiga', 'Pão'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Pão', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga', 'Pão'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'Manteiga', 'Café'}), items_add=frozenset({'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Pão', 'Café'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Manteiga', ' ', 'Café', 'Pão'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({'Manteiga', ' ', 'Pão'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({' ', 'Café'}), items_add=frozenset({'Manteiga', 'Pão'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'Manteiga', 'Café'}), items_add=frozenset({' ', 'Pão'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'Pão', 'Café'}), items_add=frozenset({'Manteiga', ' '}), confidence=1.0, lift= ...

# %%
print(saida[0])
# Out:
# RelationRecord(items=frozenset({' '}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' '}), confidence=1.0, lift=1.0)])

# %%
print(saida[1])
# Out:
# RelationRecord(items=frozenset({' ', 'Café'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Café'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)])

# %%
print(saida[2])
# Out:
# RelationRecord(items=frozenset({'Manteiga', ' '}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({' '}), confidence=1.0, lift=1.0)])

# %% [markdown]
# **Para facilitar a visualização, veja como transformar isso em um dataframe**
#
# Extraído de:
#
# https://www.section.io/engineering-education/apriori-algorithm-in-python/
#
# https://splunktool.com/understanding-apyoris-output

# %%
Antecedente = []
Consequente = []
suporte = []
confianca = []
lift = []

for resultado in saida:
  s = resultado[1]
  result_rules = resultado[2]
  for result_rule in result_rules:
    a = list(result_rule[0])
    b = list(result_rule[1])
    c = result_rule[2]
    l = result_rule[3]
    if 'nan' in a or 'nan' in b: continue
    if len(a) == 0 or len(b) == 0: continue
    Antecedente.append(a)
    Consequente.append(b)
    suporte.append(s)
    confianca.append(c)
    lift.append(l)
    RegrasFinais = pd.DataFrame({'Antecedente': Antecedente, 'Consequente': Consequente, 'suporte': suporte, 'confianca': confianca, 'lift': lift})

# %%
RegrasFinais
# Out:
#               Antecedente         Consequente  suporte  confianca  lift
# 0                  [Café]                 [ ]      0.3        1.0   1.0
# 1              [Manteiga]                 [ ]      0.5        1.0   1.0
# 2                   [Pão]                 [ ]      0.5        1.0   1.0
# 3                  [Café]          [Manteiga]      0.3        1.0   2.0
# 4                  [Café]               [Pão]      0.3        1.0   2.0
# 5              [Manteiga]               [Pão]      0.4        0.8   1.6
# 6                   [Pão]          [Manteiga]      0.4        0.8   1.6
# 7                  [Café]       [Manteiga,  ]      0.3        1.0   2.0
# 8               [ , Café]          [Manteiga]      0.3        1.0   2.0
# 9        [Manteiga, Café]                 [ ]      0.3        1.0   1.0
# 10                 [Café]            [ , Pão]      0.3        1.0   2.0
# 11              [ , Café]               [Pão]      0.3        1.0   2.0
# 12            [Pão, Café]                 [ ]      0.3        1.0   1.0
# 13             [Manteiga]            [ , Pão]      0.4        0.8   1.6
# 14                  [Pão]       [Manteiga,  ]      0.4        0.8   1.6
# 15          [Manteiga,  ]               [Pão]      0.4        0.8   1.6
# 16               [ , Pão]          [Manteiga]      0.4        0.8   1.6
# 17        [Manteiga, Pão]                 [ ]      0.4        1.0   1.0
# 18                 [Café]     [Manteiga, Pão]      0.3        1.0   2.5
# 19       [Manteiga, Café]               [Pão]      0.3        1.0   2.0
# 20            [Pão, Café]          [Manteiga]      0.3        1.0   2.0
# 21                 [Café]  [Manteiga,  , Pão]      0.3        1.0   2.5
# 22              [ , Café]     [Manteiga, Pão]      0.3        1.0   2.5
# 23       [Manteiga, Café]            [ , Pão]      0.3        1.0   2.0
# 24            [Pão, Café]       [Manteiga,  ]      0.3        1.0   2.0
# 25    [Manteiga,  , Café]               [Pão]      0.3        1.0   2.0
# 26         [ , Café, Pão]          [Manteiga]      0.3        1.0   2.0
# 27  [Manteiga, Pão, Café]                 [ ]      0.3        1.0   1.0

# %% [markdown]
# **Podemos ordenar estas regras por uma métrica desejada**

# %%
RegrasFinais.sort_values(by='lift', ascending =False)
# Out:
#               Antecedente         Consequente  suporte  confianca  lift
# 18                 [Café]     [Manteiga, Pão]      0.3        1.0   2.5
# 22              [ , Café]     [Manteiga, Pão]      0.3        1.0   2.5
# 21                 [Café]  [Manteiga,  , Pão]      0.3        1.0   2.5
# 10                 [Café]            [ , Pão]      0.3        1.0   2.0
# 25    [Manteiga,  , Café]               [Pão]      0.3        1.0   2.0
# 19       [Manteiga, Café]               [Pão]      0.3        1.0   2.0
# 23       [Manteiga, Café]            [ , Pão]      0.3        1.0   2.0
# 24            [Pão, Café]       [Manteiga,  ]      0.3        1.0   2.0
# 11              [ , Café]               [Pão]      0.3        1.0   2.0
# 20            [Pão, Café]          [Manteiga]      0.3        1.0   2.0
# 8               [ , Café]          [Manteiga]      0.3        1.0   2.0
# 7                  [Café]       [Manteiga,  ]      0.3        1.0   2.0
# 4                  [Café]               [Pão]      0.3        1.0   2.0
# 3                  [Café]          [Manteiga]      0.3        1.0   2.0
# 26         [ , Café, Pão]          [Manteiga]      0.3        1.0   2.0
# 6                   [Pão]          [Manteiga]      0.4        0.8   1.6
# 13             [Manteiga]            [ , Pão]      0.4        0.8   1.6
# 5              [Manteiga]               [Pão]      0.4        0.8   1.6
# 15          [Manteiga,  ]               [Pão]      0.4        0.8   1.6
# 16               [ , Pão]          [Manteiga]      0.4        0.8   1.6
# 14                  [Pão]       [Manteiga,  ]      0.4        0.8   1.6
# 0                  [Café]                 [ ]      0.3        1.0   1.0
# 17        [Manteiga, Pão]                 [ ]      0.4        1.0   1.0
# 1              [Manteiga]                 [ ]      0.5        1.0   1.0
# 12            [Pão, Café]                 [ ]      0.3        1.0   1.0
# 9        [Manteiga, Café]                 [ ]      0.3        1.0   1.0
# 2                   [Pão]                 [ ]      0.5        1.0   1.0
# 27  [Manteiga, Pão, Café]                 [ ]      0.3        1.0   1.0
